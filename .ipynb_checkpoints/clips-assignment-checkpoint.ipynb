# %%
import sys 

#works for both google colab and docker. installs clips, no need to push a new version of the image. 
# !pip install clipspy

#for google co-lab only! please uncomment the below lines. 
#!git clone https://github.com/andrewspiteri/module9-assignment.git

inCoLab = 'google.colab' in sys.modules
# Out:
# Collecting clipspy
#   Downloading clipspy-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (875 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.7/875.7 kB 2.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from clipspy) (1.15.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.0->clipspy) (2.21)
# Installing collected packages: clipspy
# Successfully installed clipspy-1.0.0

# %%
import pandas as pd
import clips

# %%
baseds = pd.read_csv('https://github.com/luminati-io/Amazon-popular-books-dataset/blob/main/Amazon_popular_books_dataset.csv?raw=true')

print(baseds.shape)

baseds.head(baseds.shape[0])
# Out:
# (2269, 40)
#             asin         ISBN10  answered_questions availability  \
# 0     0007350813     0007350813                   0    In Stock.
# 1     0007513763  9780007513765                   0    In Stock.
# 2     0008183988     0008183988                   0          NaN
# 3     0008305838     0008305838                   0    In Stock.
# 4     0008375526     0008375526                   0    In Stock.
# ...          ...            ...                 ...          ...
# 2264  B07P5BPVGM            NaN                   0          NaN
# 2265  B07P5JBCFL            NaN                   0          NaN
# 2266  B07NF7DFS2            NaN                   0          NaN
# 2267  B07P67N918            NaN                   0          NaN
# 2268  B07PFY8K2N            NaN                   0          NaN
#
#                                                   brand currency  \
# 0                                          Emily Brontë      USD
# 1                                          Drew Daywalt      USD
# 2                                      Bernard Cornwell      USD
# 3                                        David Walliams      USD
# 4                                       Caroline Hirons      USD
# ...                                                 ...      ...
# 2264                                        Jess Lourey      USD
# 2265  Heidi Murkoff (Author, Narrator), Meeghan Hola...      USD
# 2266  Clea Shearer (Author, Narrator), Joanna Teplin...      USD
# 2267  Lisa Jewell (Author), Tamaryn Payne (Narrator)...      USD
# 2268  Elton John (Author, Narrator), Taron Egerton (...      USD
#
#      date_first_available                                           delivery  \
# 0                     NaN  ["FREE delivery Tuesday, December 28 if you sp...
# 1                     NaN  ["FREE delivery Tuesday, December 28 if you sp...
# 2                     NaN  ["FREE delivery January 4 - 10 if you spend $2...
# 3                     NaN  ["FREE delivery Tuesday, December 28 if you sp...
# 4                     NaN  ["FREE delivery Tuesday, December 28","Or fast...
# ...                   ...                                                ...
# 2264                  NaN                                                 []
# 2265                  NaN                                                 []
# 2266                  NaN                                                 []
# 2267                  NaN                                                 []
# 2268                  NaN                                                 []
#
#       department description  ...  upc                                   url  \
# 0            NaN         NaN  ...  NaN  https://www.amazon.com/dp/0007350813
# 1            NaN         NaN  ...  NaN  https://www.amazon.com/dp/0007513763
# 2            NaN         NaN  ...  NaN  https://www.amazon.com/dp/0008183988
# 3            NaN         NaN  ...  NaN  https://www.amazon.com/dp/0008305838
# 4            NaN         NaN  ...  NaN  https://www.amazon.com/dp/0008375526
# ...          ...         ...  ...  ...                                   ...
# 2264         NaN         NaN  ...  NaN  https://www.amazon.com/dp/B07P5BPVGM
# 2265         NaN         NaN  ...  NaN  https://www.amazon.com/dp/B07P5JBCFL
# 2266         NaN         NaN  ...  NaN  https://www.amazon.com/dp/B07NF7DFS2
# 2267         NaN         NaN  ...  NaN  https://www.amazon.com/dp/B07P67N918
# 2268         NaN         NaN  ...  NaN  https://www.amazon.com/dp/B07PFY8K2N
#
#      video  video_count                                         categories  \
# 0      NaN            0   ["Books","Literature & Fiction","Genre Fiction"]
# 1      NaN            0  ["Books","Children's Books","Literature & Fict...
# 2      NaN            0   ["Books","Literature & Fiction","Genre Fiction"]
# 3      NaN            0  ["Books","Children's Books","Literature & Fict...
# 4      NaN            0  ["Books","Crafts, Hobbies & Home","Home Improv...
# ...    ...          ...                                                ...
# 2264   NaN            0  ["Books","Mystery, Thriller & Suspense","Thril...
# 2265   NaN            0  ["Books","Health, Fitness & Dieting","Women's ...
# 2266   NaN            0  ["Books","Crafts, Hobbies & Home","Home Improv...
# 2267   NaN            0  ["Books","Mystery, Thriller & Suspense","Thril...
# 2268   NaN            0  ["Books","Arts & Photography","Music","Musical...
#
#                                       best_sellers_rank         buybox_seller  \
# 0     [{"category":"Books / Literature & Fiction / H...                   NaN
# 1     [{"category":"Books / Children's Books / Liter...     VMG Books & Media
# 2     [{"category":"Books / Literature & Fiction / H...           Reuseaworld
# 3     [{"category":"Books / Children's Books / Liter...         Bahamut Media
# 4     [{"category":"Books / Health, Fitness & Dietin...  KathrynAshleyGallery
# ...                                                 ...                   ...
# 2264  [{"category":"Books / Mystery, Thriller & Susp...                   NaN
# 2265  [{"category":"Books / Health, Fitness & Dietin...                   NaN
# 2266  [{"category":"Audible Books & Originals / Home...                   NaN
# 2267  [{"category":"Audible Books & Originals / Myst...                   NaN
# 2268  [{"category":"Audible Books & Originals / Arts...                   NaN
#
#       image number_of_sellers colors
# 0       NaN               NaN    NaN
# 1       NaN               NaN    NaN
# 2       NaN               NaN    NaN
# 3       NaN               NaN    NaN
# 4       NaN               NaN    NaN
# ...     ...               ...    ...
# 2264    NaN               NaN    NaN
# 2265    NaN               NaN    NaN
# 2266    NaN               NaN    NaN
# 2267    NaN               NaN    NaN
# 2268    NaN               NaN    NaN
#
# [2269 rows x 40 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#this requires to run pip install missingno
#import missingno
#it does give an overall very good idea about the situation of the fields. 
#missingno.matrix(baseds, figsize = (30,10))

#alternativly this can be constructed manually, but not rapresneted as good in terms of where the distribution of data is. 

dataset_stats = dict()
#the inverse of the row count, to compute the % na 
r = 1 / baseds.shape[0]

#go through each column, and get the % of fields that are na. since this is (0-1) mutiply by 100 to make it more human
for column in baseds.columns:
    dataset_stats[column] = r * baseds[column].isna().sum() * 100

#some basic settings to make the plot visible. 
fig, ax = plt.subplots(figsize=(30, 20))
sns.set(font_scale=1)

#sns doesn't like array seems to prefer lists.
sns.barplot(y=list(dataset_stats.keys()), x=list(dataset_stats.values()), orient = "h")

del ax, column, dataset_stats, fig, r

# %%
#drop the columns we don't need, since there are quite a few, 
#this is split on multiple lines to make it more readable. 
baseds.drop(['answered_questions','currency','date_first_available', 'department', 'domain','features'], inplace=True, axis=1)
baseds.drop(['manufacturer','model_number','plus_content','product_dimensions', 'upc', 'video','video_count'], inplace=True, axis=1)
baseds.drop(['buybox_seller','image','number_of_sellers','colors', 'description', 'delivery'], inplace=True, axis=1)

# %%
#as well we want only to recomend books that are in stock. Drop rows for books that are not marked in stock. 
#should this have been a real time system, a filter is a better choice. 

rowindex = baseds[baseds['availability'] != 'In Stock.'].index
baseds.drop(rowindex, axis=0, inplace=True)

#one of the rows has this cell empty. 
baseds.dropna(subset=['best_sellers_rank'], inplace=True)
 
#cleanup the memory
del rowindex 

baseds.shape
# Out:
# (1249, 21)

# %%
#intialize the clips enviorment. 
environment = clips.Environment()

#this makes the kernel crash less after reload. 
environment.reset();
basepath = '';

if (inCoLab): basepath = './module9-assignment/'

#load our classes. 
environment.load(basepath + 'templates.clp')
environment.load(basepath + 'rules.clp')

# %% [markdown]
# Helper functions to populate clips facts from data.

# %%
import json 
import re  

def get_list_as_clips(items):

    result = ""
    for i in items: 
        result += f' "{cleanstr(i)}"' 

    return result 

def cleanstr(s):
    return re.sub("['\"]", "", s)


#helper function to convert a pandas row to a fact. 
#unforunatly i could not manage to find a more efficient way. 
#there is a way to convert to dictionary and load the dictionary inside clips 
#however this requires to initiaze the fact too, which made it impossible. 
def to_clips_fact(env, r):  

    #parse the json   
    jcategories = json.loads(r["categories"])
    #all categories have books category. 
    if ('Books' in jcategories): jcategories.remove('Books')
    #clean special chars
    jcategories = [cleanstr(item) for item in jcategories]

    jrankcategorie = json.loads(r["best_sellers_rank"])

    #each row rapresents a book, and each book might be in multiple category ranks 
    #this will create a distinct fact per rank.
    for n in jrankcategorie:
        rcat = n['category'].split(' / ') 

        #clean any chars that might break clips. 
        rcat = [cleanstr(item) for item in rcat]

        #again rank category have books in all of them. 
        if ('Books' in rcat): rcat.remove('Books')

        factstr = f'(amazonbook (asin "{r["asin"]}") (ISBN10 "{r["ISBN10"]}") (title "{cleanstr(r["title"])}")  (categories {get_list_as_clips(jcategories)}) (rankcategories {get_list_as_clips(rcat)}) (rank {n["rank"]}) )'
        #print(factstr) #for debugging issues..
        env.assert_string(factstr)
                            
  
for _, row in baseds.iterrows():
    to_clips_fact(environment, row)


del row

# %%
#user input.

books = [   "Skincare: The award-winning ultimate no-nonsense guide and Sunday Times No. 1 best-seller",
            "Homo Deus: A Brief History of Tomorrow"
            "The Bad Seed (The Food Group)"
            "The Rose Code: A Novel",
            "Divergent",
            "Divergent / Insurgent",
            "Insurgent (Divergent Series, 2)",
            "Allegiant",
            "Allegiant (Divergent Series, 3)",
            "The 48 Laws of Power"]


environment.assert_string(f'(request (id "1") (preferences {get_list_as_clips(books)}))')
# Out:
# TemplateFact: (request (id "1") (preferences "Skincare: The award-winning ultimate no-nonsense guide and Sunday Times No. 1 best-seller" "Homo Deus: A Brief History of TomorrowThe Bad Seed (The Food Group)The Rose Code: A Novel" "Divergent" "Divergent / Insurgent" "Insurgent (Divergent Series, 2)" "Allegiant" "Allegiant (Divergent Series, 3)" "The 48 Laws of Power"))

# %%
#this is for debugging. 
#environment.eval("(watch facts)")
#environment.eval("(watch activations)")

#this took me a lot of time to figure out!
environment.eval("(run)")

recommended_books = environment.eval("(find-all-facts ((?rb book_recommendation)) TRUE)")
 
                                                                              
for rb in recommended_books:
    print(rb['requestid'],". ASIN: ", rb['asin'], ", Title:", rb['title'] , " in category by rank ", rb['rankcategories'], "(Rank ", rb['rank'], ")" )
 
#debugging..
#for fact in environment.facts():
#    print(fact)
# Out:
# 1 . ASIN:  1982148039 , Title: The Room Where It Happened: A White House Memoir  in category by rank  ('Politics & Social Sciences', 'Politics & Government', 'Political Science', 'History & Theory') (Rank  31 )
# 1 . ASIN:  1982182911 , Title: Peril  in category by rank  ('Biographies & Memoirs', 'Historical', 'United States') (Rank  4 )
# 1 . ASIN:  0345816021 , Title: 12 Rules for Life: An Antidote to Chaos  in category by rank  ('Politics & Social Sciences', 'Philosophy', 'Social Philosophy') (Rank  2 )
# 1 . ASIN:  1438241569 , Title: The Communist Manifesto  in category by rank  ('Politics & Social Sciences', 'Philosophy', 'Political') (Rank  96 )
# 1 . ASIN:  0063142783 , Title: The Boy, the Mole, the Fox and the Horse Deluxe (Yellow) Edition  in category by rank  ('Politics & Social Sciences', 'Philosophy', 'Ethics & Morality') (Rank  71 )
# 1 . ASIN:  1989201512 , Title: The Art of War  in category by rank  ('Politics & Social Sciences', 'Politics & Government', 'Political Science', 'Reference') (Rank  28 )
# 1 . ASIN:  081298160X , Title: The Power of Habit: Why We Do What We Do in Life and Business  in category by rank  ('Health, Fitness & Dieting', 'Psychology & Counseling', 'Social Psychology & Interactions') (Rank  18 )
# 1 . ASIN:  1592408419 , Title: Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead  in category by rank  ('Business & Money', 'Business Culture', 'Motivation & Self-Improvement') (Rank  8 )
# 1 . ASIN:  1594634726 , Title: Big Magic: Creative Living Beyond Fear  in category by rank  ('Business & Money', 'Management & Leadership', 'Motivational') (Rank  36 )
# 1 . ASIN:  1591846447 , Title: Start with Why: How Great Leaders Inspire Everyone to Take Action  in category by rank  ('Business & Money', 'Management & Leadership', 'Leadership & Motivation') (Rank  10 )
# 1 . ASIN:  1846041090 , Title: Women Who Run With The Wolves: Contacting the Power of the Wild Woman (Classic Edition)  in category by rank  ('Health, Fitness & Dieting', 'Psychology & Counseling', 'Child Psychology') (Rank  99 )
# 1 . ASIN:  1878424319 , Title: The Four Agreements: A Practical Guide to Personal Freedom (A Toltec Wisdom Book)  in category by rank  ('Self-Help', 'Success') (Rank  1 )
